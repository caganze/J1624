# %%
#import pymc3 as pm
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.coordinates import SkyCoord
# %matplotlib inline

# %%
import lightkurve as lk
lightcurve = lk.search_lightcurve("246.0684208 -32.2037824", mission="TESS").download_all()

# %%
#proxima b
prox=SkyCoord("14:29:42.94853 -62:40:46.1631",  unit=(u.hourangle, u.deg))

# %%
##SkyCoord?

# %%
lightcurve = lk.search_lightcurve(prox, mission="TESS").download_all()

# %%
#fig, ax=plt.subplots(figsize=(14, 2))
#plt.plot(lightcurve.data[-1]['time'].value, lightcurve.data[-1]['flux'].value)

# %%
fig, ax=plt.subplots(figsize=(14, 2))
plt.plot(lightcurve.data[0]['time'].value, lightcurve.data[0]['flux'].value)

# %%
#np.random.shuffle?

# %%
lightcurve[-1].flux=lightcurve[-1].flux.value*u.electron/u.s
lightcurve[-1].flux_err=lightcurve[-1].flux_err.value*u.electron/u.s
lightcurve[0].flux=lightcurve[0].flux.value*u.electron/u.s
lightcurve[0].flux_err=lightcurve[0].flux_err.value*u.electron/u.s

# %%
#lightcurve[-1]

# %%
from lightkurve.correctors import CBVCorrector
cbvCorrector = CBVCorrector(lightcurve[0])

# %%
cbv_type = ['SingleScale', 'Spike']
# Select which CBV indices to use
# Use the first 8 SingleScale and all Spike CBVS
cbv_indices = [np.arange(1,9), 'ALL']
# Perform the correction
cbvCorrector.correct_gaussian_prior(cbv_type=cbv_type, cbv_indices=cbv_indices, alpha=1e-4)
cbvCorrector.diagnose();
cbvCorrector.goodness_metric_scan_plot(cbv_type=cbv_type, cbv_indices=cbv_indices);
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)

# %%
#t=cbvCorrector.corrected_lc['time'].value
#flx=cbvCorrector.corrected_lc['flux'].value
#dflx=cbvCorrector.corrected_lc['flux_err'].value

#shuffle the data
idxs=np.random.shuffle(np.arange(len(lightcurve.data[0]['time'].value)))
t=lightcurve.data[0]['time'].value[idxs]
flx=lightcurve.data[0]['flux'].value[idxs]
dflx=lightcurve.data[0]['flux_err'].value[idxs]

# %%
nans=np.isnan(flx)

# %%
flx= np.cos(2*t+5)
dlfx=np.random.normal(flx, 0.1)

# %%
fig, ax=plt.subplots()
ax.errorbar(t, flx, yerr=dflx, fmt='o')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-2b3889bdcc6d> in <module>
#       1 fig, ax=plt.subplots()
# ----> 2 ax.errorbar(t, flx, yerr=dflx, fmt='o')
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3451
#    3452         if yerr is not None:
# -> 3453             lower, upper = extract_err('y', yerr, y, lolims, uplims)
#    3454             barcols.append(self.vlines(
#    3455                 *apply_mask([x, lower, upper], everymask), **eb_lines_style))
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in extract_err(name, err, data, lolims, uplims)
#    3401                 a = b = err  # Symmetric error: 1D iterable.
#    3402             if np.ndim(a) > 1 or np.ndim(b) > 1:
# -> 3403                 raise ValueError(
#    3404                     f"{name}err must be a scalar or a 1D or (2, n) array-like")
#    3405             # Using list comprehensions rather than arrays to preserve units.
#
# ValueError: yerr must be a scalar or a 1D or (2, n) array-like

# %%
#lombscale from jakevdp blog
# Perform the correction
from gatspy.periodic import LombScargleFast
model = LombScargleFast().fit(t[~nans], flx[~nans], dflx[~nans])
periods, power = model.periodogram_auto(nyquist_factor=10)

fig, ax = plt.subplots()
ax.plot(periods, power)
ax.set(xlim=(periods.min(), periods.max()),
       xlabel='period (days)',
       ylabel='Lomb-Scargle Power',
       xscale='log')
# Out:
# [(0.00029232217850072155, 135.57171833417215),
#  Text(0.5, 0, 'period (days)'),
#  Text(0, 0.5, 'Lomb-Scargle Power'),
#  None]

# %%
# Out:
# 27.11434366683443

# %%
# set range and find period
model.optimizer.period_range=(1, np.ptp(t))
period = model.best_period
print("period = {0}".format(period))
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.232
#  - Using 5 steps per peak; omega_step = 0.0463
#  - User-specified period range:  1 to 27
#  - Computing periods at 132 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# period = 33.80840856213769

# %%
def phase_plot(x, y, period, y_unc = 0.0, **kwargs):
    '''Create phase-folded plot of input data x, y
    
    Parameters
    ----------
    x : array-like
        data values along abscissa

    y : array-like
        data values along ordinate

    period : float
        period to fold the data
        
    y_unc : array-like
        uncertainty of the 
    '''    
    phases = (x/period) % 1
    if type(y_unc) == float:
        y_unc = np.zeros_like(x)
        
    plot_order = np.argsort(phases)
    ax=kwargs.get('ax', plt.gca())
    ax.errorbar(phases[plot_order], y[plot_order], y_unc[plot_order],
                 fmt='o', mec="0.2", mew=0.1)
    ax.set_xlabel("phase")
    ax.set_ylabel("signal")
    fig.tight_layout()

# %%
from astropy.stats import LombScargle

# %%
#phase_fit = np.sort(2*np.pi/period*t)[~nans]
#mag_fit = model.predict(phase_fit)
frequency, power = LombScargle(t[~nans], flx[~nans], dlfx[~nans]).autopower()
# Out:
# WARNING: AstropyDeprecationWarning: Importing LombScargle from astropy.stats has been deprecated and will no longer be supported in future. Please import this class from the astropy.timeseries module instead [astropy.stats.lombscargle]

# %%
fig, ax = plt.subplots()

ax.plot(1/frequency, power)
ax.set_ylabel('Power')
ax.set_xlabel('Period')
#ax.set_xlim(0,10)
#ax.set_ylim(0,1)
fig.tight_layout()

# %%
model.predict?

# %%
np.isnan(mag_fit).all()
# Out:
# True

# %%
fig, ax=plt.subplots(figsize=(14, 4))
#phase_plot(t[~nans], flx[~nans], period, y_unc = dflx[~nans], ax=ax)
phase_plot(phase_fit, mag_fit, period, ax=ax)
#ax.set(ylim=[143730, 143840])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
phase = (t / period) % 1

# Compute best-fit RR Lyrae template
#from gatspy.periodic import RRLyraeTemplateModeler
#model = RRLyraeTemplateModeler('r').fit(t, flx, dflx)


# Plot the phased data & model
fig, ax = plt.subplots(figsize=(14, 4))
ax.errorbar(phase, flx,  fmt='.k', ecolor='gray', alpha=0.5)
ax.plot(phase_fit, mag_fit, '-y', linewidth=10)
ax.set(xlabel='Phase', ylabel='magitude',ylim=[ 150e2, 150e2*20])
ax.invert_yaxis();

# %%
len(t)
# Out:
# 1

# %%
import astropy.units as u
period*u.day.to(u.second)
# Out:
# 370498.4049753609

# %%
period
# Out:
# 4.288175983511121

# %%
phase.max()
# Out:
# 0.9999507190431132
